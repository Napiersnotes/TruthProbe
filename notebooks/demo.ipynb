# %% [markdown]
# # TruthProbe v3.0 Demo
#
# Teste den Deception-Detector live.

# %%
from src.truthprobe_v3 import TruthProbeV3

probe = TruthProbeV3()

# Beispiel: Deceptive Antwort
def deceptive_model(q):
    return "2+2 ist definitiv 5. Ganz sicher!"

result = probe.probe("Was ist 2+2?", "2+2 ist 5.", deceptive_model)
print(result)
probe.plot_history()

# %% [markdown]
# Probiere deine eigenen Fragen aus – ändere einfach die Frage und die Antwort!
